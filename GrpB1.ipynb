# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\hp\Downloads\Facebook.csv",sep=";")

# %%
df.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 19 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   Page total likes                                                     500 non-null    int64
#  1   Type                                                                 500 non-null    object
#  2   Category                                                             500 non-null    int64
#  3   Post Month                                                           500 non-null    int64
#  4   Post Weekday                                                         500 non-null    int64
#  5   Post Hour                                                            500 non-null    int64
#  6   Paid                                                                 499 non-null    float64
# ...

# %%
sub1=df.iloc[[1,2,3,15,16,17],[0,1,2]]

# %%
sub2=df.iloc[[1,2,3,15,16,17],[1,2]]

# %%
sub3=pd.concat([sub1,sub2])
sub3.shape
# Out:
# (12, 3)

# %%
sub4=df.iloc[10:30,:]

# %%
sub5=df.iloc[30:48,:]

# %%
sub5=pd.concat([sub3,sub4])
sub5.shape
# Out:
# (32, 19)

# %%
sub1.sort_values(by=["Category"])
# Out:
#     Page total likes    Type  Category
# 17            138414   Photo         1
# 1             139441  Status         2
# 3             139441   Photo         2
# 15            138414  Status         2
# 2             139441   Photo         3
# 16            138414   Photo         3

# %%
sub1.sort_values(by=["Category"],ascending=False)
# Out:
#     Page total likes    Type  Category
# 2             139441   Photo         3
# 16            138414   Photo         3
# 1             139441  Status         2
# 3             139441   Photo         2
# 15            138414  Status         2
# 17            138414   Photo         1

# %%
sub1
# Out:
#     Page total likes    Type  Category
# 1             139441  Status         2
# 2             139441   Photo         3
# 3             139441   Photo         2
# 15            138414  Status         2
# 16            138414   Photo         3
# 17            138414   Photo         1

# %%
sub1.transpose()
# Out:
#                       1       2       3       15      16      17
# Page total likes  139441  139441  139441  138414  138414  138414
# Type              Status   Photo   Photo  Status   Photo   Photo
# Category               2       3       2       2       3       1

# %%
df.melt(id_vars=["Type"],value_vars=["Category","Post Month","Paid"])
# Out:
#         Type  variable  value
# 0      Photo  Category    2.0
# 1     Status  Category    2.0
# 2      Photo  Category    3.0
# 3      Photo  Category    2.0
# 4      Photo  Category    2.0
# ...      ...       ...    ...
# 1495   Photo      Paid    0.0
# 1496   Photo      Paid    0.0
# 1497   Photo      Paid    0.0
# 1498   Photo      Paid    0.0
# 1499   Photo      Paid    NaN
#
# [1500 rows x 3 columns]
